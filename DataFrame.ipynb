# %% [markdown]
# # Dataframe is main object in pandas. it is used to represent data with raws and columns

# %% [markdown]
# ## Topics

# %% [markdown]
# # 1) Creating Dataframe

# %% [markdown]
# # 2) Dealing with Raws and columns

# %% [markdown]
# # 3) Operations : Min,Max,std,describe

# %% [markdown]
# # 4) Conditional selection

# %%
import pandas as pd

# %%
data=pd.read_csv('accient.csv')

# %%
data[4:10]
# Out:
#         ID                    Date     DateType   Age     Sex          Race  \
# 4  13-0052  02/13/2013 12:00:00 AM  DateofDeath  22.0    Male  Asian, Other
# 5  14-0277  06/29/2014 12:00:00 AM  DateofDeath  23.0    Male         White
# 6  12-0205  08/12/2012 12:00:00 AM  DateofDeath  21.0  Female         White
# 7  13-0404  11/10/2013 12:00:00 AM  DateofDeath  40.0  Female         White
# 8  12-0107  04/25/2012 12:00:00 AM  DateofDeath  40.0    Male         White
# 9  13-0161  05/15/2013 12:00:00 AM  DateofDeath  50.0    Male         White
#
#    ResidenceCity ResidenceCounty ResidenceState      DeathCity  ... Tramad  \
# 4       FLUSHING          QUEENS            NaN      GREENWICH  ...    NaN
# 5        BRISTOL             NaN            NaN        BRISTOL  ...    NaN
# 6  WEST HARTFORD        HARTFORD            NaN  WEST HARTFORD  ...    NaN
# 7         HAMDEN       NEW HAVEN            NaN      NEW HAVEN  ...    NaN
# ...

# %%
data[1:2]
# Out:
#         ID                    Date     DateType   Age   Sex   Race  \
# 1  13-0102  03/21/2013 12:00:00 AM  DateofDeath  48.0  Male  Black
#
#   ResidenceCity ResidenceCounty ResidenceState DeathCity  ... Tramad  \
# 1       NORWALK             NaN            NaN   NORWALK  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 1                NaN           NaN   NaN       NaN       NaN      Accident
#
#                           DeathCityGeo                     ResidenceCityGeo  \
# 1  Norwalk, CT\n(41.11805, -73.412906)  NORWALK, CT\n(41.11805, -73.412906)
#
#                  InjuryCityGeo
# 1  CT\n(41.575155, -72.738288)
#
# [1 rows x 41 columns]

# %%
data.columns
# Out:
# Index(['ID', 'Date', 'DateType', 'Age', 'Sex', 'Race', 'ResidenceCity',
#        'ResidenceCounty', 'ResidenceState', 'DeathCity', 'DeathCounty',
#        'Location', 'LocationifOther', 'DescriptionofInjury', 'InjuryPlace',
#        'InjuryCity', 'InjuryCounty', 'InjuryState', 'COD', 'OtherSignifican',
#        'Heroin', 'Cocaine', 'Fentanyl', 'FentanylAnalogue', 'Oxycodone',
#        'Oxymorphone', 'Ethanol', 'Hydrocodone', 'Benzodiazepine', 'Methadone',
#        'Amphet', 'Tramad', 'Morphine_NotHeroin', 'Hydromorphone', 'Other',
#        'OpiateNOS', 'AnyOpioid', 'MannerofDeath', 'DeathCityGeo',
#        'ResidenceCityGeo', 'InjuryCityGeo'],
#       dtype='object')

# %%
for i in data.columns:
    
    print(i)
# Out:
# ID
# Date
# DateType
# Age
# Sex
# Race
# ResidenceCity
# ResidenceCounty
# ResidenceState
# DeathCity
# DeathCounty
# Location
# LocationifOther
# DescriptionofInjury
# InjuryPlace
# InjuryCity
# InjuryCounty
# InjuryState
# COD
# OtherSignifican
# Heroin
# Cocaine
# Fentanyl
# FentanylAnalogue
# Oxycodone
# Oxymorphone
# Ethanol
# Hydrocodone
# Benzodiazepine
# Methadone
# Amphet
# Tramad
# Morphine_NotHeroin
# Hydromorphone
# Other
# OpiateNOS
# AnyOpioid
# MannerofDeath
# DeathCityGeo
# ResidenceCityGeo
# InjuryCityGeo

# %%
data['Age']
# Out:
# 0        NaN
# 1       48.0
# 2       30.0
# 3       23.0
# 4       22.0
#         ...
# 5100    43.0
# 5101    21.0
# 5102    30.0
# 5103    33.0
# 5104    33.0
# Name: Age, Length: 5105, dtype: float64

# %%
data[['Age','COD']]
# Out:
#        Age                                                COD
# 0      NaN               Acute fent, hydrocod, benzodiazepine
# 1     48.0                               Cocaine Intoxication
# 2     30.0              Acute Heroin and Cocaine Intoxication
# 3     23.0           Acute Fentanyl and Morphine Intoxication
# 4     22.0                              Fentanyl Intoxication
# ...    ...                                                ...
# 5100  43.0  Acute Intoxication due to the Combined Effects...
# 5101  21.0  Multidrug Toxicity Including Heroin, Alprazola...
# 5102  30.0  Multidrug Toxicity Including Heroin, Fentanyl,...
# 5103  33.0                        Acute Fentanyl intoxication
# 5104  33.0                          Acute Heroin Intoxication
#
# [5105 rows x 2 columns]

# %%
data[['ID','Age']]
# Out:
#            ID   Age
# 0     14-0273   NaN
# 1     13-0102  48.0
# 2     16-0165  30.0
# 3     16-0208  23.0
# 4     13-0052  22.0
# ...       ...   ...
# 5100  15-0466  43.0
# 5101  17-0618  21.0
# 5102  18-0646  30.0
# 5103  14-0124  33.0
# 5104  16-0637  33.0
#
# [5105 rows x 2 columns]

# %%
df.Age.max()
# Out:
# 87.0

# %%
df.Age.describe()
# Out:
# count    5102.000000
# mean       41.964916
# std        12.336639
# min        14.000000
# 25%        32.000000
# 50%        42.000000
# 75%        52.000000
# max        87.000000
# Name: Age, dtype: float64

# %%
df.Age.mean()
# Out:
# 41.96491571932575

# %%
df[df.Age>50]
# Out:
#            ID                    Date      DateType   Age     Sex  \
# 18    16-0065  01/30/2016 12:00:00 AM   DateofDeath  54.0    Male
# 26    18-0095  02/10/2018 12:00:00 AM  DateReported  51.0    Male
# 35    15-0475  09/14/2015 12:00:00 AM  DateReported  51.0    Male
# 37    15-0314  06/28/2015 12:00:00 AM  DateReported  55.0  Female
# 38    15-0687  12/07/2015 12:00:00 AM  DateReported  56.0    Male
# ...       ...                     ...           ...   ...     ...
# 5083  17-0242  03/22/2017 12:00:00 AM  DateReported  58.0  Female
# 5085  13-0341  10/08/2013 12:00:00 AM   DateofDeath  51.0    Male
# 5086  12-0222  08/27/2012 12:00:00 AM   DateofDeath  71.0    Male
# 5096  16-0520  07/31/2016 12:00:00 AM   DateofDeath  54.0  Female
# 5098  14-0166  04/17/2014 12:00:00 AM   DateofDeath  56.0    Male
#
#                  Race ResidenceCity ResidenceCounty ResidenceState  \
# 18              White    MIDDLETOWN       MIDDLESEX             CT
# ...

# %%
df[df.Age==30].head()
# Out:
#           ID                    Date      DateType   Age     Sex   Race  \
# 2    16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female  White
# 49   16-0610  09/05/2016 12:00:00 AM   DateofDeath  30.0    Male  White
# 92   17-0745  09/11/2017 12:00:00 AM  DateReported  30.0  Female  White
# 98   14-0447  10/25/2014 12:00:00 AM   DateofDeath  30.0  Female  White
# 121  15-0494  09/22/2015 12:00:00 AM  DateReported  30.0    Male  White
#
#      ResidenceCity ResidenceCounty ResidenceState      DeathCity  ... Tramad  \
# 2       SANDY HOOK       FAIRFIELD             CT        DANBURY  ...    NaN
# 49          BALTIC      NEW LONDON             CT         BALTIC  ...    NaN
# 92         NEWTOWN       FAIRFIELD             CT        DANBURY  ...    NaN
# 98   EAST HARTFORD             NaN            NaN  EAST HARTFORD  ...    NaN
# 121        DANBURY       FAIRFIELD             CT        DANBURY  ...    NaN
#
# ...

# %%
df[df.Age==df.Age.max()]
# Out:
#            ID                    Date     DateType   Age   Sex  \
# 2534  13-0235  07/14/2013 12:00:00 AM  DateofDeath  87.0  Male
#
#                  Race ResidenceCity ResidenceCounty ResidenceState  DeathCity  \
# 2534  Hispanic, White     NEW HAVEN       NEW HAVEN            NaN  NEW HAVEN
#
#       ... Tramad Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid  \
# 2534  ...    NaN                NaN           NaN   NaN       NaN       NaN
#
#      MannerofDeath                            DeathCityGeo  \
# 2534      Accident  NEW HAVEN, CT\n(41.308252, -72.924161)
#
#                             ResidenceCityGeo                InjuryCityGeo
# 2534  NEW HAVEN, CT\n(41.308252, -72.924161)  CT\n(41.575155, -72.738288)
#
# [1 rows x 41 columns]
